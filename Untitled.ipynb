# %%
data = np.random.normal(0, 1, 1000)
sns.kdeplot(data=data, color='blue', shade=True, label='KDE Plot')
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Kernel Density Estimation (KDE) Plot')
plt.legend()
plt.show()
