# %% [markdown]
# # The goal is to perform dimentiality reduction for future model building.
# Initial steps are just to build default models, that could fit available memory
# and make a submission on Kaggle.

# %%
#jupyter notebook --NotebookApp.max_buffer_size=35536870912 
# to run jupyter notebook using more available memory
import os, gc, pickle, scipy.sparse, time, h5py, anndata, hdf5plugin#, lightgbm
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.decomposition import PCA
#from sklearn.svm import SVR takes way too long
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error
#import scanpy as sc
import anndata
import hdf5plugin
from sys import getsizeof
from sklearn.decomposition import TruncatedSVD
from sklearn.pipeline import Pipeline
import joblib
import h5py
from scipy.sparse import csr_matrix
from math import sqrt
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
import seaborn as sns

data_path = "/home/skovtun/Single cell/Single_cell_data"
metadata = os.path.join(data_path,"metadata.csv")

train_cite_inputs = os.path.join(data_path,"train_cite_inputs.h5")
train_cite_targets = os.path.join(data_path,"train_cite_targets.h5")
test_cite_inputs = os.path.join(data_path,"test_cite_inputs.h5")

train_multi_inputs = os.path.join(data_path,"train_multi_inputs.h5")
train_multi_targets = os.path.join(data_path,"train_multi_targets.h5")
test_multi_inputs = os.path.join(data_path,"test_multi_inputs.h5")

sample_submission = os.path.join(data_path,"sample_submission.csv")
evaluation_ids = os.path.join(data_path,"evaluation_ids.csv")

# %%
# Getting indexes of cell_id for train and test samples.
import csv

cite_train_sample = []
cite_test_sample = []
multi_train_sample = []
multi_test_sample = []
with open('cite_train_sample.csv', 'r') as csvfile:
    reader = csv.reader(csvfile)
    for row in reader:
        cite_train_sample.append(row)

with open('cite_test_sample.csv', 'r') as csvfile:
    reader = csv.reader(csvfile)
    for row in reader:
        cite_test_sample.append(row)

with open('multi_train_sample.csv', 'r') as csvfile:
    reader = csv.reader(csvfile)
    for row in reader:
        multi_train_sample.append(row)

with open('multi_test_sample.csv', 'r') as csvfile:
    reader = csv.reader(csvfile)
    for row in reader:
        multi_test_sample.append(row)
multi_train_sample = [item for sublist in multi_train_sample for item in sublist]
multi_test_sample = [item for sublist in multi_test_sample for item in sublist]

cite_train_sample = [item for sublist in cite_train_sample for item in sublist]
cite_test_sample = [item for sublist in cite_test_sample for item in sublist]

# %%
print(len(multi_train_sample),len(multi_test_sample), len(cite_train_sample), len(cite_test_sample))
# Out:
# 129500 32377 95720 23931

# %%
# Read the h5 file and extract the dataset values and corresponding rows
def sparse_matrix_from_file( data_file_path,data_key, filter_list):
    """
    Given path to the h5 file data_file_path and list of cells filter_list, name of the data_key,
    creates a sparse
    matrix of rows in h5 file that belongs to the cells_id from the filter_list
    """
    with h5py.File(data_file_path, 'r') as h5file:
        data = h5file[data_key]['block0_values']
        rows = h5file[data_key]['axis1'][:]
    
        # Convert rows to regular strings
        rows = [item.decode('utf-8') for item in rows]
        
        # Initialize an empty list to store selected_data in chunks
        selected_data_chunks = []
        
        # Set the chunk size (adjust as needed)
        chunk_size = 1000
        data_list = []
        indices_list = []
        indptr_list = [0]  # Initialize with 0
        # Iterate through the data in chunks
        for start_idx in range(0, len(rows), chunk_size):
            end_idx = start_idx + chunk_size
            print(start_idx, end_idx)
            
            # Create a boolean mask for the current chunk
            chunk_mask = np.isin(rows[start_idx:end_idx], filter_list)
            
            # Use the mask to select the corresponding rows from the current chunk of data
            chunk_data = data[start_idx:end_idx][chunk_mask]
            
            
            # Process the chunk, convert to CSR format
            processed_chunk_sparse = csr_matrix(chunk_data)
                    
            # Update indptr and store the data and indices
            indptr_list.extend(processed_chunk_sparse.indptr[1:] + indptr_list[-1])
            data_list.append(processed_chunk_sparse.data)
            indices_list.append(processed_chunk_sparse.indices)
        
            
        # Combine the lists into arrays
        values = np.concatenate(data_list)
        indices = np.concatenate(indices_list)
        indptr = np.array(indptr_list)
        
        # Create the final CSR sparse matrix
        sparse_matrix = csr_matrix((values, indices, indptr)) 
    return sparse_matrix

# %%
#Read dataset for test_multiome and conver it to sparse matrix
multi_train_sparse_matrix = sparse_matrix_from_file( train_multi_inputs,'train_multi_inputs', multi_train_sample)
# Out:
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 10000
# 10000 11000
# 11000 12000
# 12000 13000
# 13000 14000
# 14000 15000
# 15000 16000
# 16000 17000
# 17000 18000
# 18000 19000
# 19000 20000
# 20000 21000
# 21000 22000
# 22000 23000
# 23000 24000
# 24000 25000
# 25000 26000
# 26000 27000
# 27000 28000
# 28000 29000
# 29000 30000
# 30000 31000
# 31000 32000
# 32000 33000
# 33000 34000
# 34000 35000
# 35000 36000
# 36000 37000
# 37000 38000
# 38000 39000
# 39000 40000
# 40000 41000
# 41000 42000
# 42000 43000
# 43000 44000
# 44000 45000
# 45000 46000
# 46000 47000
# 47000 48000
# 48000 49000
# 49000 50000
# 50000 51000
# 51000 52000
# 52000 53000
# 53000 54000
# 54000 55000
# 55000 56000
# 56000 57000
# 57000 58000
# 58000 59000
# 59000 60000
# 60000 61000
# 61000 62000
# 62000 63000
# 63000 64000
# 64000 65000
# 65000 66000
# 66000 67000
# 67000 68000
# 68000 69000
# 69000 70000
# 70000 71000
# 71000 72000
# 72000 73000
# 73000 74000
# 74000 75000
# 75000 76000
# 76000 77000
# 77000 78000
# 78000 79000
# 79000 80000
# 80000 81000
# 81000 82000
# 82000 83000
# 83000 84000
# 84000 85000
# 85000 86000
# 86000 87000
# 87000 88000
# 88000 89000
# 89000 90000
# 90000 91000
# 91000 92000
# 92000 93000
# 93000 94000
# 94000 95000
# 95000 96000
# 96000 97000
# 97000 98000
# 98000 99000
# 99000 100000
# 100000 101000
# 101000 102000
# 102000 103000
# 103000 104000
# 104000 105000
# 105000 106000

# %%
# Read the h5 file and extract the dataset values and corresponding rows
filter_list  = multi_train_sample
with h5py.File(train_multi_inputs, 'r') as h5file:
    data = h5file['train_multi_inputs']['block0_values']
    rows = h5file['train_multi_inputs']['axis1'][:]

    # Convert rows to regular strings
    rows = [item.decode('utf-8') for item in rows]
    
    # Initialize an empty list to store selected_data in chunks
    selected_data_chunks = []
    
    # Set the chunk size (adjust as needed)
    chunk_size = 1000
    data_list = []
    indices_list = []
    indptr_list = [0]  # Initialize with 0
    # Iterate through the data in chunks
    for start_idx in range(0, len(rows), chunk_size):
        end_idx = start_idx + chunk_size
        print(start_idx, end_idx)
        
        # Create a boolean mask for the current chunk
        chunk_mask = np.isin(rows[start_idx:end_idx], filter_list)
        
        # Use the mask to select the corresponding rows from the current chunk of data
        chunk_data = data[start_idx:end_idx][chunk_mask]
        
        
        # Process the chunk, convert to CSR format
        processed_chunk_sparse = csr_matrix(chunk_data)
                
        # Update indptr and store the data and indices
        indptr_list.extend(processed_chunk_sparse.indptr[1:] + indptr_list[-1])
        data_list.append(processed_chunk_sparse.data)
        indices_list.append(processed_chunk_sparse.indices)
    
        
    # Combine the lists into arrays
    values = np.concatenate(data_list)
    indices = np.concatenate(indices_list)
    indptr = np.array(indptr_list)
    
# Create the final CSR sparse matrix
multi_train_sparse_matrix = csr_matrix((values, indices, indptr))
# Out:
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 10000
# 10000 11000
# 11000 12000
# 12000 13000
# 13000 14000
# 14000 15000
# 15000 16000
# 16000 17000
# 17000 18000
# 18000 19000
# 19000 20000
# 20000 21000
# 21000 22000
# 22000 23000
# 23000 24000
# 24000 25000
# 25000 26000
# 26000 27000
# 27000 28000
# 28000 29000
# 29000 30000
# 30000 31000
# 31000 32000
# 32000 33000
# 33000 34000
# 34000 35000
# 35000 36000
# 36000 37000
# 37000 38000
# 38000 39000
# 39000 40000
# 40000 41000
# 41000 42000
# 42000 43000
# 43000 44000
# 44000 45000
# 45000 46000
# 46000 47000
# 47000 48000
# 48000 49000
# 49000 50000
# 50000 51000
# 51000 52000
# 52000 53000
# 53000 54000
# 54000 55000
# 55000 56000
# 56000 57000
# 57000 58000
# 58000 59000
# 59000 60000
# 60000 61000
# 61000 62000
# 62000 63000
# 63000 64000
# 64000 65000
# 65000 66000
# 66000 67000
# 67000 68000
# 68000 69000
# 69000 70000
# 70000 71000
# 71000 72000
# 72000 73000
# 73000 74000
# 74000 75000
# 75000 76000
# 76000 77000
# 77000 78000
# 78000 79000
# 79000 80000
# 80000 81000
# 81000 82000
# 82000 83000
# 83000 84000
# 84000 85000
# 85000 86000
# 86000 87000
# 87000 88000
# 88000 89000
# 89000 90000
# 90000 91000
# 91000 92000
# 92000 93000
# 93000 94000
# 94000 95000
# 95000 96000
# 96000 97000
# 97000 98000
# 98000 99000
# 99000 100000
# 100000 101000
# 101000 102000
# 102000 103000
# 103000 104000
# 104000 105000
# 105000 106000

# %%
multi_train_sparse_matrix.shape
# Out:
# (84548, 228942)

# %%
#TruncatedSVD
# 6000 components explains ~70% of variance
# from sklearn.decomposition import TruncatedSVD
# start_time = time.time()
# svd_multi = TruncatedSVD(n_components=150, n_iter=7, random_state=42)
# svd_multi.fit(multi_train_sparse_matrix)
# print(svd_multi.explained_variance_ratio_.sum())
# print(f"--- {time.time() - start_time} seconds ---")
# 0.012246355
# --- 800.2067103385925 seconds ---
# Out:
# 0.012246355
# --- 800.2067103385925 seconds ---

# %%
#TruncatedSVD
# 6000 components explains ~70% of variance
from sklearn.decomposition import TruncatedSVD
start_time = time.time()
svd_multi_500 = TruncatedSVD(n_components=500, n_iter=7, random_state=42)
svd_multi_500.fit(multi_train_sparse_matrix)
print(svd_multi_500.explained_variance_ratio_.sum())
print(f"--- {time.time() - start_time} seconds ---")
#0.02362837
#--- 1864.4796884059906 seconds ---
# Out:
# 0.02362837
# --- 1883.9215996265411 seconds ---

# %%
multi_train_500 = svd_multi_500.transform(multi_train_sparse_matrix)

# %%
multi_train_500.shape
# Out:
# (84548, 500)

# %%
# from scipy.sparse.linalg import svds
# import numpy as np

# # Specify the number of components (right singular vectors) you want to retain
# n_components = 150  # Decrease the number of components
# start_time = time.time()
# # Perform sparse SVD on the large sparse matrix X
# _, _, Vt = svds(multi_train_sparse_matrix, k=n_components)  # X is your large sparse matrix
# #Y_transformed = Y.dot(Vt.T)
# print(f"--- {time.time() - start_time} seconds ---")
# #--- 3585.899343729019 seconds ---
# # it is way too long compared to TrancadedSVD
# Out:
# --- 3585.899343729019 seconds ---

# %%
#checking if one of the methods works faster for SVD

# %%
# Our targets for multi will be inputs for citeseq. So, we need to get citeseq,
# normalize it and perform dimentionality reduction first.
# Then we apply this transformation for multi targets. And then tune and build XGBRegressor models 
# for new targets.
train_cite = pd.read_hdf(train_cite_inputs)

# %%
train_cite.shape
# Out:
# (70988, 22050)

# %%
start_time = time.time()
pipeline = Pipeline([('scaling', StandardScaler()), ('pca', PCA(n_components=200, random_state=42))])
pipeline.fit_transform(train_cite)
print(f"--- {time.time() - start_time} seconds ---")
print(pipeline.named_steps['pca'].explained_variance_ratio_.sum())
# PCA(n_components=200,
# --- 67.58247065544128 seconds ---
# 0.08761159987095953
# This is for future, if I want to improve
# Out:
# --- 67.58247065544128 seconds ---
# 0.08761159987095953

# %%
# Inverse transform to get back to the original dimension
# I will need it to make a predition for submission.
original_data = pipeline.named_steps['pca'].inverse_transform(transformed_data)

# %%
# Reading targets for multiome and creating a dataset corresponding to the rows
# whit the cell_id multi_train_sample I have in train_multi dataset .

target = h5py.File(train_multi_targets,'r')#, mode)
cell_id = target['train_multi_targets']['axis1'][:]
# Convert rows to regular strings
cell_id = [item.decode('utf-8') for item in cell_id]
# Create a boolean mask for the current chunk
rows_mask = np.isin(cell_id, multi_train_sample)
# Use the mask to select the corresponding rows from the current chunk of data
target_multi_train = target['train_multi_targets']['block0_values'][rows_mask,:]
target_multi_train.shape
# Out:
# (84548, 23418)

# %%
# Next step is to apply pipeline to theese targets.
#target_train_200 = pipeline.transform(target_multi_train)
# ok, I wrongfully assumed that number of targets for mulitome is the same as number of features
#for citeseq. But cityseq has 22050 features, and multiome has 23418 targets.
# So, there will be independent pipelines for dimentiality reduction for them.
start_time = time.time()
pipeline_target_200 = Pipeline([('scaling', StandardScaler()), ('pca', PCA(n_components=200, random_state=42))])
target_multi_train_200 = pipeline_target_200.fit_transform(target_multi_train)
print(f"--- {time.time() - start_time} seconds ---")
print(pipeline_target_200.named_steps['pca'].explained_variance_ratio_.sum())
# Out:
# --- 84.33351445198059 seconds ---
# 0.07105860961131216

# %%
target_multi_train_200.shape
# Out:
# (84548, 200)

# %%
#Read dataset for test_multiome and conver it to sparse matrix
multi_test_sparse_matrix = sparse_matrix_from_file( train_multi_inputs,'train_multi_inputs', multi_test_sample)
# Out:
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 10000
# 10000 11000
# 11000 12000
# 12000 13000
# 13000 14000
# 14000 15000
# 15000 16000
# 16000 17000
# 17000 18000
# 18000 19000
# 19000 20000
# 20000 21000
# 21000 22000
# 22000 23000
# 23000 24000
# 24000 25000
# 25000 26000
# 26000 27000
# 27000 28000
# 28000 29000
# 29000 30000
# 30000 31000
# 31000 32000
# 32000 33000
# 33000 34000
# 34000 35000
# 35000 36000
# 36000 37000
# 37000 38000
# 38000 39000
# 39000 40000
# 40000 41000
# 41000 42000
# 42000 43000
# 43000 44000
# 44000 45000
# 45000 46000
# 46000 47000
# 47000 48000
# 48000 49000
# 49000 50000
# 50000 51000
# 51000 52000
# 52000 53000
# 53000 54000
# 54000 55000
# 55000 56000
# 56000 57000
# 57000 58000
# 58000 59000
# 59000 60000
# 60000 61000
# 61000 62000
# 62000 63000
# 63000 64000
# 64000 65000
# 65000 66000
# 66000 67000
# 67000 68000
# 68000 69000
# 69000 70000
# 70000 71000
# 71000 72000
# 72000 73000
# 73000 74000
# 74000 75000
# 75000 76000
# 76000 77000
# 77000 78000
# 78000 79000
# 79000 80000
# 80000 81000
# 81000 82000
# 82000 83000
# 83000 84000
# 84000 85000
# 85000 86000
# 86000 87000
# 87000 88000
# 88000 89000
# 89000 90000
# 90000 91000
# 91000 92000
# 92000 93000
# 93000 94000
# 94000 95000
# 95000 96000
# 96000 97000
# 97000 98000
# 98000 99000
# 99000 100000
# 100000 101000
# 101000 102000
# 102000 103000
# 103000 104000
# 104000 105000
# 105000 106000

# %%
multi_test_sparse_matrix.shape
# Out:
# (21394, 228942)

# %%
# Apply TrancateSVD to this dataset
multi_test_500 = svd_multi_500.transform(multi_test_sparse_matrix)

# %%
multi_test_500.shape
# Out:
# (21394, 500)

# %%
# Read targets for test_mulitome
# Reading targets for multiome and creating a dataset corresponding to the rows
# whit the cell_id multi_test_sample that I have in test_multi.

target = h5py.File(train_multi_targets,'r')#, mode)
cell_id = target['train_multi_targets']['axis1'][:]
# Convert rows to regular strings
cell_id = [item.decode('utf-8') for item in cell_id]
# Create a boolean mask for the current chunk
rows_mask_test = np.isin(cell_id, multi_test_sample)
# Use the mask to select the corresponding rows from the current chunk of data
target_multi_test = target['train_multi_targets']['block0_values'][rows_mask_test,:]
#target_train = target['train_multi_targets']['block0_values'][multi_train_sample,:]
#target_test = target['train_multi_targets']['block0_values'][multi_test_sample,:]
target_multi_test.shape
# Out:
# (21394, 23418)

# %%
sum(rows_mask_test)
# Out:
# 21394

# %%
# Apply pipeline to this dataset
target_multi_test_200 = pipeline_target_200.transform(target_multi_test)

# %%
target_multi_test_200.shape
# Out:
# (21394, 200)

# %%
# Find the best parameters for XGBRegressor for target 1.
# Open question. Should we search for best parameters for every target or the set of the parameters 
# will be the same???
# build a model on train_multi
# test on test_multi
start_time = time.time()
# Create an instance of XGBRegressor
xgb_model = XGBRegressor(n_jobs=-1,tree_method="gpu_hist", sampling_method='gradient_based')
#X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.2, random_state=3)

# Define the parameter grid for GridSearchCV
param_grid = {
    #'n_estimators': [100, 200, 300],
    'max_depth': [3, 5, 7, 9],
    'learning_rate': [0.1, 0.5, 1, 10],
    'min_child_weight': [1, 5, 100],
    #'subsample': [0.7, 0.8, 0.9],
    #'colsample_bytree': [0.7, 0.8, 0.9],
    'reg_alpha': [1, 5, 100],
    'reg_lambda': [1, 5, 100]
}

# Create a GridSearchCV instance
grid_search = GridSearchCV(estimator=xgb_model, param_grid=param_grid, 
                           cv=5, scoring='neg_mean_squared_error',verbose = 3)

# Fit the GridSearchCV instance on the data
grid_search.fit(multi_train_500, target_multi_train_200[:,0])

# Print the best parameters
best_params = grid_search.best_params_
print("Best parameters:", best_params)
# Out:
# Fitting 5 folds for each of 432 candidates, totalling 2160 fits
# [CV 1/5] END learning_rate=0.1, max_depth=3, min_child_weight=1, reg_alpha=1, reg_lambda=1;, score=-131.048 total time=   2.6s
# [CV 2/5] END learning_rate=0.1, max_depth=3, min_child_weight=1, reg_alpha=1, reg_lambda=1;, score=-140.856 total time=   1.9s
# [CV 3/5] END learning_rate=0.1, max_depth=3, min_child_weight=1, reg_alpha=1, reg_lambda=1;, score=-138.577 total time=   1.9s
# [CV 4/5] END learning_rate=0.1, max_depth=3, min_child_weight=1, reg_alpha=1, reg_lambda=1;, score=-173.983 total time=   1.9s
# [CV 5/5] END learning_rate=0.1, max_depth=3, min_child_weight=1, reg_alpha=1, reg_lambda=1;, score=-156.741 total time=   1.9s
# [CV 1/5] END learning_rate=0.1, max_depth=3, min_child_weight=1, reg_alpha=1, reg_lambda=5;, score=-132.562 total time=   1.9s
# [CV 2/5] END learning_rate=0.1, max_depth=3, min_child_weight=1, reg_alpha=1, reg_lambda=5;, score=-142.010 total time=   1.9s
# [CV 3/5] END learning_rate=0.1, max_depth=3, min_child_weight=1, reg_alpha=1, reg_lambda=5;, score=-139.069 total time=   1.9s
# [CV 4/5] END learning_rate=0.1, max_depth=3, min_child_weight=1, reg_alpha=1, reg_lambda=5;, score=-174.494 total time=   1.9s
# [CV 5/5] END learning_rate=0.1, max_depth=3, min_child_weight=1, reg_alpha=1, reg_lambda=5;, score=-158.324 total time=   1.9s
# [CV 1/5] END learning_rate=0.1, max_depth=3, min_child_weight=1, reg_alpha=1, reg_lambda=100;, score=-133.340 total time=   1.9s
# [CV 2/5] END learning_rate=0.1, max_depth=3, min_child_weight=1, reg_alpha=1, reg_lambda=100;, score=-141.566 total time=   1.9s
# [CV 3/5] END learning_rate=0.1, max_depth=3, min_child_weight=1, reg_alpha=1, reg_lambda=100;, score=-139.582 total time=   1.9s
# [CV 4/5] END learning_rate=0.1, max_depth=3, min_child_weight=1, reg_alpha=1, reg_lambda=100;, score=-174.764 total time=   1.9s
# [CV 5/5] END learning_rate=0.1, max_depth=3, min_child_weight=1, reg_alpha=1, reg_lambda=100;, score=-158.062 total time=   1.9s
# [CV 1/5] END learning_rate=0.1, max_depth=3, min_child_weight=1, reg_alpha=5, reg_lambda=1;, score=-131.297 total time=   1.9s
# [CV 2/5] END learning_rate=0.1, max_depth=3, min_child_weight=1, reg_alpha=5, reg_lambda=1;, score=-141.838 total time=   1.9s
# [CV 3/5] END learning_rate=0.1, max_depth=3, min_child_weight=1, reg_alpha=5, reg_lambda=1;, score=-139.303 total time=   1.9s
# [CV 4/5] END learning_rate=0.1, max_depth=3, min_child_weight=1, reg_alpha=5, reg_lambda=1;, score=-174.040 total time=   1.9s
# [CV 5/5] END learning_rate=0.1, max_depth=3, min_child_weight=1, reg_alpha=5, reg_lambda=1;, score=-157.681 total time=   1.9s
# [CV 1/5] END learning_rate=0.1, max_depth=3, min_child_weight=1, reg_alpha=5, reg_lambda=5;, score=-132.625 total time=   1.9s
# [CV 2/5] END learning_rate=0.1, max_depth=3, min_child_weight=1, reg_alpha=5, reg_lambda=5;, score=-143.331 total time=   1.9s
# [CV 3/5] END learning_rate=0.1, max_depth=3, min_child_weight=1, reg_alpha=5, reg_lambda=5;, score=-138.922 total time=   1.9s
# [CV 4/5] END learning_rate=0.1, max_depth=3, min_child_weight=1, reg_alpha=5, reg_lambda=5;, score=-173.881 total time=   1.9s
# [CV 5/5] END learning_rate=0.1, max_depth=3, min_child_weight=1, reg_alpha=5, reg_lambda=5;, score=-157.949 total time=   1.9s
# [CV 1/5] END learning_rate=0.1, max_depth=3, min_child_weight=1, reg_alpha=5, reg_lambda=100;, score=-132.694 total time=   1.9s
# [CV 2/5] END learning_rate=0.1, max_depth=3, min_child_weight=1, reg_alpha=5, reg_lambda=100;, score=-142.019 total time=   1.9s
# [CV 3/5] END learning_rate=0.1, max_depth=3, min_child_weight=1, reg_alpha=5, reg_lambda=100;, score=-139.544 total time=   1.9s
# [CV 4/5] END learning_rate=0.1, max_depth=3, min_child_weight=1, reg_alpha=5, reg_lambda=100;, score=-174.529 total time=   1.9s
# [CV 5/5] END learning_rate=0.1, max_depth=3, min_child_weight=1, reg_alpha=5, reg_lambda=100;, score=-158.476 total time=   1.9s
# [CV 1/5] END learning_rate=0.1, max_depth=3, min_child_weight=1, reg_alpha=100, reg_lambda=1;, score=-132.154 total time=   1.9s
# [CV 2/5] END learning_rate=0.1, max_depth=3, min_child_weight=1, reg_alpha=100, reg_lambda=1;, score=-142.148 total time=   1.9s
# [CV 3/5] END learning_rate=0.1, max_depth=3, min_child_weight=1, reg_alpha=100, reg_lambda=1;, score=-138.719 total time=   1.9s
# [CV 4/5] END learning_rate=0.1, max_depth=3, min_child_weight=1, reg_alpha=100, reg_lambda=1;, score=-175.114 total time=   1.9s
# [CV 5/5] END learning_rate=0.1, max_depth=3, min_child_weight=1, reg_alpha=100, reg_lambda=1;, score=-157.395 total time=   1.9s
# [CV 1/5] END learning_rate=0.1, max_depth=3, min_child_weight=1, reg_alpha=100, reg_lambda=5;, score=-132.862 total time=   1.9s
# [CV 2/5] END learning_rate=0.1, max_depth=3, min_child_weight=1, reg_alpha=100, reg_lambda=5;, score=-142.414 total time=   1.9s
# [CV 3/5] END learning_rate=0.1, max_depth=3, min_child_weight=1, reg_alpha=100, reg_lambda=5;, score=-139.221 total time=   1.9s
# [CV 4/5] END learning_rate=0.1, max_depth=3, min_child_weight=1, reg_alpha=100, reg_lambda=5;, score=-174.341 total time=   1.9s
# [CV 5/5] END learning_rate=0.1, max_depth=3, min_child_weight=1, reg_alpha=100, reg_lambda=5;, score=-158.045 total time=   1.9s
# [CV 1/5] END learning_rate=0.1, max_depth=3, min_child_weight=1, reg_alpha=100, reg_lambda=100;, score=-133.018 total time=   1.9s
# [CV 2/5] END learning_rate=0.1, max_depth=3, min_child_weight=1, reg_alpha=100, reg_lambda=100;, score=-143.089 total time=   1.9s
# [CV 3/5] END learning_rate=0.1, max_depth=3, min_child_weight=1, reg_alpha=100, reg_lambda=100;, score=-140.012 total time=   1.9s
# [CV 4/5] END learning_rate=0.1, max_depth=3, min_child_weight=1, reg_alpha=100, reg_lambda=100;, score=-174.383 total time=   1.9s
# [CV 5/5] END learning_rate=0.1, max_depth=3, min_child_weight=1, reg_alpha=100, reg_lambda=100;, score=-159.187 total time=   1.9s
# [CV 1/5] END learning_rate=0.1, max_depth=3, min_child_weight=5, reg_alpha=1, reg_lambda=1;, score=-131.046 total time=   1.9s
# [CV 2/5] END learning_rate=0.1, max_depth=3, min_child_weight=5, reg_alpha=1, reg_lambda=1;, score=-140.847 total time=   1.9s
# [CV 3/5] END learning_rate=0.1, max_depth=3, min_child_weight=5, reg_alpha=1, reg_lambda=1;, score=-138.577 total time=   1.9s
# [CV 4/5] END learning_rate=0.1, max_depth=3, min_child_weight=5, reg_alpha=1, reg_lambda=1;, score=-173.982 total time=   1.9s
# [CV 5/5] END learning_rate=0.1, max_depth=3, min_child_weight=5, reg_alpha=1, reg_lambda=1;, score=-156.741 total time=   1.9s
# [CV 1/5] END learning_rate=0.1, max_depth=3, min_child_weight=5, reg_alpha=1, reg_lambda=5;, score=-132.567 total time=   1.9s
# [CV 2/5] END learning_rate=0.1, max_depth=3, min_child_weight=5, reg_alpha=1, reg_lambda=5;, score=-142.010 total time=   1.9s
# [CV 3/5] END learning_rate=0.1, max_depth=3, min_child_weight=5, reg_alpha=1, reg_lambda=5;, score=-139.069 total time=   1.9s
# [CV 4/5] END learning_rate=0.1, max_depth=3, min_child_weight=5, reg_alpha=1, reg_lambda=5;, score=-174.494 total time=   1.9s
# [CV 5/5] END learning_rate=0.1, max_depth=3, min_child_weight=5, reg_alpha=1, reg_lambda=5;, score=-158.324 total time=   1.9s
# [CV 1/5] END learning_rate=0.1, max_depth=3, min_child_weight=5, reg_alpha=1, reg_lambda=100;, score=-133.340 total time=   1.9s
# [CV 2/5] END learning_rate=0.1, max_depth=3, min_child_weight=5, reg_alpha=1, reg_lambda=100;, score=-141.566 total time=   1.9s
# [CV 3/5] END learning_rate=0.1, max_depth=3, min_child_weight=5, reg_alpha=1, reg_lambda=100;, score=-139.582 total time=   1.9s
# [CV 4/5] END learning_rate=0.1, max_depth=3, min_child_weight=5, reg_alpha=1, reg_lambda=100;, score=-174.764 total time=   1.9s
# [CV 5/5] END learning_rate=0.1, max_depth=3, min_child_weight=5, reg_alpha=1, reg_lambda=100;, score=-158.062 total time=   1.9s
# [CV 1/5] END learning_rate=0.1, max_depth=3, min_child_weight=5, reg_alpha=5, reg_lambda=1;, score=-131.298 total time=   1.9s
# [CV 2/5] END learning_rate=0.1, max_depth=3, min_child_weight=5, reg_alpha=5, reg_lambda=1;, score=-141.760 total time=   1.9s
# [CV 3/5] END learning_rate=0.1, max_depth=3, min_child_weight=5, reg_alpha=5, reg_lambda=1;, score=-138.767 total time=   1.9s
# [CV 4/5] END learning_rate=0.1, max_depth=3, min_child_weight=5, reg_alpha=5, reg_lambda=1;, score=-174.039 total time=   1.9s
# [CV 5/5] END learning_rate=0.1, max_depth=3, min_child_weight=5, reg_alpha=5, reg_lambda=1;, score=-157.681 total time=   1.9s
# [CV 1/5] END learning_rate=0.1, max_depth=3, min_child_weight=5, reg_alpha=5, reg_lambda=5;, score=-132.630 total time=   1.9s
# [CV 2/5] END learning_rate=0.1, max_depth=3, min_child_weight=5, reg_alpha=5, reg_lambda=5;, score=-143.331 total time=   1.9s
# [CV 3/5] END learning_rate=0.1, max_depth=3, min_child_weight=5, reg_alpha=5, reg_lambda=5;, score=-138.922 total time=   1.9s
# [CV 4/5] END learning_rate=0.1, max_depth=3, min_child_weight=5, reg_alpha=5, reg_lambda=5;, score=-173.875 total time=   1.9s
# [CV 5/5] END learning_rate=0.1, max_depth=3, min_child_weight=5, reg_alpha=5, reg_lambda=5;, score=-157.949 total time=   1.9s
# [CV 1/5] END learning_rate=0.1, max_depth=3, min_child_weight=5, reg_alpha=5, reg_lambda=100;, score=-132.694 total time=   1.9s
# [CV 2/5] END learning_rate=0.1, max_depth=3, min_child_weight=5, reg_alpha=5, reg_lambda=100;, score=-142.019 total time=   1.9s
# [CV 3/5] END learning_rate=0.1, max_depth=3, min_child_weight=5, reg_alpha=5, reg_lambda=100;, score=-139.544 total time=   1.9s
# [CV 4/5] END learning_rate=0.1, max_depth=3, min_child_weight=5, reg_alpha=5, reg_lambda=100;, score=-174.529 total time=   1.9s
# [CV 5/5] END learning_rate=0.1, max_depth=3, min_child_weight=5, reg_alpha=5, reg_lambda=100;, score=-158.476 total time=   1.9s
# [CV 1/5] END learning_rate=0.1, max_depth=3, min_child_weight=5, reg_alpha=100, reg_lambda=1;, score=-132.154 total time=   1.9s
# [CV 2/5] END learning_rate=0.1, max_depth=3, min_child_weight=5, reg_alpha=100, reg_lambda=1;, score=-142.148 total time=   1.9s
# [CV 3/5] END learning_rate=0.1, max_depth=3, min_child_weight=5, reg_alpha=100, reg_lambda=1;, score=-138.719 total time=   1.9s
# [CV 4/5] END learning_rate=0.1, max_depth=3, min_child_weight=5, reg_alpha=100, reg_lambda=1;, score=-175.114 total time=   1.9s
# [CV 5/5] END learning_rate=0.1, max_depth=3, min_child_weight=5, reg_alpha=100, reg_lambda=1;, score=-157.395 total time=   1.9s
# [CV 1/5] END learning_rate=0.1, max_depth=3, min_child_weight=5, reg_alpha=100, reg_lambda=5;, score=-132.862 total time=   1.9s
# [CV 2/5] END learning_rate=0.1, max_depth=3, min_child_weight=5, reg_alpha=100, reg_lambda=5;, score=-142.414 total time=   1.9s
# [CV 3/5] END learning_rate=0.1, max_depth=3, min_child_weight=5, reg_alpha=100, reg_lambda=5;, score=-139.221 total time=   1.9s
# [CV 4/5] END learning_rate=0.1, max_depth=3, min_child_weight=5, reg_alpha=100, reg_lambda=5;, score=-174.338 total time=   1.9s
# [CV 5/5] END learning_rate=0.1, max_depth=3, min_child_weight=5, reg_alpha=100, reg_lambda=5;, score=-158.045 total time=   1.9s
# [CV 1/5] END learning_rate=0.1, max_depth=3, min_child_weight=5, reg_alpha=100, reg_lambda=100;, score=-133.018 total time=   1.9s
# [CV 2/5] END learning_rate=0.1, max_depth=3, min_child_weight=5, reg_alpha=100, reg_lambda=100;, score=-143.089 total time=   1.9s
# [CV 3/5] END learning_rate=0.1, max_depth=3, min_child_weight=5, reg_alpha=100, reg_lambda=100;, score=-140.012 total time=   1.9s
# [CV 4/5] END learning_rate=0.1, max_depth=3, min_child_weight=5, reg_alpha=100, reg_lambda=100;, score=-174.383 total time=   1.9s
# [CV 5/5] END learning_rate=0.1, max_depth=3, min_child_weight=5, reg_alpha=100, reg_lambda=100;, score=-159.187 total time=   1.9s
# [CV 1/5] END learning_rate=0.1, max_depth=3, min_child_weight=100, reg_alpha=1, reg_lambda=1;, score=-131.357 total time=   1.9s
# [CV 2/5] END learning_rate=0.1, max_depth=3, min_child_weight=100, reg_alpha=1, reg_lambda=1;, score=-142.111 total time=   1.9s
# [CV 3/5] END learning_rate=0.1, max_depth=3, min_child_weight=100, reg_alpha=1, reg_lambda=1;, score=-138.588 total time=   1.9s
# [CV 4/5] END learning_rate=0.1, max_depth=3, min_child_weight=100, reg_alpha=1, reg_lambda=1;, score=-174.410 total time=   1.9s
# [CV 5/5] END learning_rate=0.1, max_depth=3, min_child_weight=100, reg_alpha=1, reg_lambda=1;, score=-157.832 total time=   1.9s
# [CV 1/5] END learning_rate=0.1, max_depth=3, min_child_weight=100, reg_alpha=1, reg_lambda=5;, score=-132.284 total time=   1.9s
# [CV 2/5] END learning_rate=0.1, max_depth=3, min_child_weight=100, reg_alpha=1, reg_lambda=5;, score=-141.983 total time=   1.9s
# [CV 3/5] END learning_rate=0.1, max_depth=3, min_child_weight=100, reg_alpha=1, reg_lambda=5;, score=-138.910 total time=   1.9s
# [CV 4/5] END learning_rate=0.1, max_depth=3, min_child_weight=100, reg_alpha=1, reg_lambda=5;, score=-174.311 total time=   1.9s
# [CV 5/5] END learning_rate=0.1, max_depth=3, min_child_weight=100, reg_alpha=1, reg_lambda=5;, score=-157.289 total time=   1.9s
# [CV 1/5] END learning_rate=0.1, max_depth=3, min_child_weight=100, reg_alpha=1, reg_lambda=100;, score=-132.861 total time=   1.9s
# [CV 2/5] END learning_rate=0.1, max_depth=3, min_child_weight=100, reg_alpha=1, reg_lambda=100;, score=-142.890 total time=   1.9s
# [CV 3/5] END learning_rate=0.1, max_depth=3, min_child_weight=100, reg_alpha=1, reg_lambda=100;, score=-139.387 total time=   1.9s
# [CV 4/5] END learning_rate=0.1, max_depth=3, min_child_weight=100, reg_alpha=1, reg_lambda=100;, score=-174.394 total time=   1.9s
# [CV 5/5] END learning_rate=0.1, max_depth=3, min_child_weight=100, reg_alpha=1, reg_lambda=100;, score=-158.146 total time=   1.9s
# [CV 1/5] END learning_rate=0.1, max_depth=3, min_child_weight=100, reg_alpha=5, reg_lambda=1;, score=-131.212 total time=   1.9s
# [CV 2/5] END learning_rate=0.1, max_depth=3, min_child_weight=100, reg_alpha=5, reg_lambda=1;, score=-141.495 total time=   1.9s
# [CV 3/5] END learning_rate=0.1, max_depth=3, min_child_weight=100, reg_alpha=5, reg_lambda=1;, score=-139.451 total time=   1.9s
# [CV 4/5] END learning_rate=0.1, max_depth=3, min_child_weight=100, reg_alpha=5, reg_lambda=1;, score=-174.465 total time=   1.9s
# [CV 5/5] END learning_rate=0.1, max_depth=3, min_child_weight=100, reg_alpha=5, reg_lambda=1;, score=-157.844 total time=   2.0s
# [CV 1/5] END learning_rate=0.1, max_depth=3, min_child_weight=100, reg_alpha=5, reg_lambda=5;, score=-132.098 total time=   1.9s
# [CV 2/5] END learning_rate=0.1, max_depth=3, min_child_weight=100, reg_alpha=5, reg_lambda=5;, score=-142.377 total time=   1.9s
# [CV 3/5] END learning_rate=0.1, max_depth=3, min_child_weight=100, reg_alpha=5, reg_lambda=5;, score=-139.106 total time=   1.9s
# [CV 4/5] END learning_rate=0.1, max_depth=3, min_child_weight=100, reg_alpha=5, reg_lambda=5;, score=-174.081 total time=   1.9s
# [CV 5/5] END learning_rate=0.1, max_depth=3, min_child_weight=100, reg_alpha=5, reg_lambda=5;, score=-157.133 total time=   2.0s
# [CV 1/5] END learning_rate=0.1, max_depth=3, min_child_weight=100, reg_alpha=5, reg_lambda=100;, score=-132.058 total time=   1.9s
# [CV 2/5] END learning_rate=0.1, max_depth=3, min_child_weight=100, reg_alpha=5, reg_lambda=100;, score=-142.422 total time=   1.9s
# [CV 3/5] END learning_rate=0.1, max_depth=3, min_child_weight=100, reg_alpha=5, reg_lambda=100;, score=-139.410 total time=   1.9s
# [CV 4/5] END learning_rate=0.1, max_depth=3, min_child_weight=100, reg_alpha=5, reg_lambda=100;, score=-174.525 total time=   1.9s
# [CV 5/5] END learning_rate=0.1, max_depth=3, min_child_weight=100, reg_alpha=5, reg_lambda=100;, score=-158.156 total time=   2.0s
# [CV 1/5] END learning_rate=0.1, max_depth=3, min_child_weight=100, reg_alpha=100, reg_lambda=1;, score=-132.232 total time=   1.9s
# [CV 2/5] END learning_rate=0.1, max_depth=3, min_child_weight=100, reg_alpha=100, reg_lambda=1;, score=-141.215 total time=   1.9s
# [CV 3/5] END learning_rate=0.1, max_depth=3, min_child_weight=100, reg_alpha=100, reg_lambda=1;, score=-138.879 total time=   2.0s
# [CV 4/5] END learning_rate=0.1, max_depth=3, min_child_weight=100, reg_alpha=100, reg_lambda=1;, score=-174.930 total time=   1.9s
# [CV 5/5] END learning_rate=0.1, max_depth=3, min_child_weight=100, reg_alpha=100, reg_lambda=1;, score=-157.328 total time=   1.9s
# [CV 1/5] END learning_rate=0.1, max_depth=3, min_child_weight=100, reg_alpha=100, reg_lambda=5;, score=-132.290 total time=   1.9s
# [CV 2/5] END learning_rate=0.1, max_depth=3, min_child_weight=100, reg_alpha=100, reg_lambda=5;, score=-142.973 total time=   1.9s
# [CV 3/5] END learning_rate=0.1, max_depth=3, min_child_weight=100, reg_alpha=100, reg_lambda=5;, score=-139.025 total time=   1.9s
# [CV 4/5] END learning_rate=0.1, max_depth=3, min_child_weight=100, reg_alpha=100, reg_lambda=5;, score=-174.179 total time=   1.9s
# [CV 5/5] END learning_rate=0.1, max_depth=3, min_child_weight=100, reg_alpha=100, reg_lambda=5;, score=-158.072 total time=   1.9s
# [CV 1/5] END learning_rate=0.1, max_depth=3, min_child_weight=100, reg_alpha=100, reg_lambda=100;, score=-132.403 total time=   1.9s
# [CV 2/5] END learning_rate=0.1, max_depth=3, min_child_weight=100, reg_alpha=100, reg_lambda=100;, score=-142.749 total time=   1.9s
# [CV 3/5] END learning_rate=0.1, max_depth=3, min_child_weight=100, reg_alpha=100, reg_lambda=100;, score=-139.711 total time=   1.9s
# [CV 4/5] END learning_rate=0.1, max_depth=3, min_child_weight=100, reg_alpha=100, reg_lambda=100;, score=-174.870 total time=   1.9s
# [CV 5/5] END learning_rate=0.1, max_depth=3, min_child_weight=100, reg_alpha=100, reg_lambda=100;, score=-158.494 total time=   1.9s
# [CV 1/5] END learning_rate=0.1, max_depth=5, min_child_weight=1, reg_alpha=1, reg_lambda=1;, score=-122.478 total time=   2.6s
# [CV 2/5] END learning_rate=0.1, max_depth=5, min_child_weight=1, reg_alpha=1, reg_lambda=1;, score=-123.518 total time=   2.6s
# [CV 3/5] END learning_rate=0.1, max_depth=5, min_child_weight=1, reg_alpha=1, reg_lambda=1;, score=-127.738 total time=   2.6s
# [CV 4/5] END learning_rate=0.1, max_depth=5, min_child_weight=1, reg_alpha=1, reg_lambda=1;, score=-162.060 total time=   2.6s
# [CV 5/5] END learning_rate=0.1, max_depth=5, min_child_weight=1, reg_alpha=1, reg_lambda=1;, score=-140.288 total time=   2.6s
# [CV 1/5] END learning_rate=0.1, max_depth=5, min_child_weight=1, reg_alpha=1, reg_lambda=5;, score=-122.283 total time=   2.6s
# [CV 2/5] END learning_rate=0.1, max_depth=5, min_child_weight=1, reg_alpha=1, reg_lambda=5;, score=-123.165 total time=   2.6s
# [CV 3/5] END learning_rate=0.1, max_depth=5, min_child_weight=1, reg_alpha=1, reg_lambda=5;, score=-127.426 total time=   2.6s
# [CV 4/5] END learning_rate=0.1, max_depth=5, min_child_weight=1, reg_alpha=1, reg_lambda=5;, score=-162.537 total time=   2.6s
# [CV 5/5] END learning_rate=0.1, max_depth=5, min_child_weight=1, reg_alpha=1, reg_lambda=5;, score=-140.064 total time=   2.6s
# [CV 1/5] END learning_rate=0.1, max_depth=5, min_child_weight=1, reg_alpha=1, reg_lambda=100;, score=-123.609 total time=   2.6s
# [CV 2/5] END learning_rate=0.1, max_depth=5, min_child_weight=1, reg_alpha=1, reg_lambda=100;, score=-124.531 total time=   2.5s
# [CV 3/5] END learning_rate=0.1, max_depth=5, min_child_weight=1, reg_alpha=1, reg_lambda=100;, score=-128.908 total time=   2.6s
# [CV 4/5] END learning_rate=0.1, max_depth=5, min_child_weight=1, reg_alpha=1, reg_lambda=100;, score=-163.245 total time=   2.5s
# [CV 5/5] END learning_rate=0.1, max_depth=5, min_child_weight=1, reg_alpha=1, reg_lambda=100;, score=-141.413 total time=   2.5s
# [CV 1/5] END learning_rate=0.1, max_depth=5, min_child_weight=1, reg_alpha=5, reg_lambda=1;, score=-122.163 total time=   2.6s
# [CV 2/5] END learning_rate=0.1, max_depth=5, min_child_weight=1, reg_alpha=5, reg_lambda=1;, score=-123.237 total time=   2.6s
# [CV 3/5] END learning_rate=0.1, max_depth=5, min_child_weight=1, reg_alpha=5, reg_lambda=1;, score=-127.085 total time=   2.6s
# [CV 4/5] END learning_rate=0.1, max_depth=5, min_child_weight=1, reg_alpha=5, reg_lambda=1;, score=-161.887 total time=   2.6s
# [CV 5/5] END learning_rate=0.1, max_depth=5, min_child_weight=1, reg_alpha=5, reg_lambda=1;, score=-139.410 total time=   2.6s
# [CV 1/5] END learning_rate=0.1, max_depth=5, min_child_weight=1, reg_alpha=5, reg_lambda=5;, score=-122.426 total time=   2.6s
# [CV 2/5] END learning_rate=0.1, max_depth=5, min_child_weight=1, reg_alpha=5, reg_lambda=5;, score=-123.503 total time=   2.6s
# [CV 3/5] END learning_rate=0.1, max_depth=5, min_child_weight=1, reg_alpha=5, reg_lambda=5;, score=-127.791 total time=   2.6s
# [CV 4/5] END learning_rate=0.1, max_depth=5, min_child_weight=1, reg_alpha=5, reg_lambda=5;, score=-162.728 total time=   2.6s
# [CV 5/5] END learning_rate=0.1, max_depth=5, min_child_weight=1, reg_alpha=5, reg_lambda=5;, score=-140.079 total time=   2.6s
# [CV 1/5] END learning_rate=0.1, max_depth=5, min_child_weight=1, reg_alpha=5, reg_lambda=100;, score=-123.687 total time=   2.5s
# [CV 2/5] END learning_rate=0.1, max_depth=5, min_child_weight=1, reg_alpha=5, reg_lambda=100;, score=-124.426 total time=   2.5s
# [CV 3/5] END learning_rate=0.1, max_depth=5, min_child_weight=1, reg_alpha=5, reg_lambda=100;, score=-128.136 total time=   2.6s
# [CV 4/5] END learning_rate=0.1, max_depth=5, min_child_weight=1, reg_alpha=5, reg_lambda=100;, score=-163.167 total time=   2.6s
# [CV 5/5] END learning_rate=0.1, max_depth=5, min_child_weight=1, reg_alpha=5, reg_lambda=100;, score=-141.601 total time=   2.5s
# [CV 1/5] END learning_rate=0.1, max_depth=5, min_child_weight=1, reg_alpha=100, reg_lambda=1;, score=-123.185 total time=   2.6s
# [CV 2/5] END learning_rate=0.1, max_depth=5, min_child_weight=1, reg_alpha=100, reg_lambda=1;, score=-124.021 total time=   2.6s
# [CV 3/5] END learning_rate=0.1, max_depth=5, min_child_weight=1, reg_alpha=100, reg_lambda=1;, score=-127.644 total time=   2.6s
# [CV 4/5] END learning_rate=0.1, max_depth=5, min_child_weight=1, reg_alpha=100, reg_lambda=1;, score=-162.635 total time=   2.6s
# [CV 5/5] END learning_rate=0.1, max_depth=5, min_child_weight=1, reg_alpha=100, reg_lambda=1;, score=-140.577 total time=   2.6s
# [CV 1/5] END learning_rate=0.1, max_depth=5, min_child_weight=1, reg_alpha=100, reg_lambda=5;, score=-122.814 total time=   2.6s
# [CV 2/5] END learning_rate=0.1, max_depth=5, min_child_weight=1, reg_alpha=100, reg_lambda=5;, score=-124.006 total time=   2.6s
# [CV 3/5] END learning_rate=0.1, max_depth=5, min_child_weight=1, reg_alpha=100, reg_lambda=5;, score=-127.957 total time=   2.6s
# [CV 4/5] END learning_rate=0.1, max_depth=5, min_child_weight=1, reg_alpha=100, reg_lambda=5;, score=-162.088 total time=   2.6s
# [CV 5/5] END learning_rate=0.1, max_depth=5, min_child_weight=1, reg_alpha=100, reg_lambda=5;, score=-141.363 total time=   2.6s
# [CV 1/5] END learning_rate=0.1, max_depth=5, min_child_weight=1, reg_alpha=100, reg_lambda=100;, score=-123.412 total time=   2.6s
# [CV 2/5] END learning_rate=0.1, max_depth=5, min_child_weight=1, reg_alpha=100, reg_lambda=100;, score=-124.853 total time=   2.6s
# [CV 3/5] END learning_rate=0.1, max_depth=5, min_child_weight=1, reg_alpha=100, reg_lambda=100;, score=-128.155 total time=   2.6s
# [CV 4/5] END learning_rate=0.1, max_depth=5, min_child_weight=1, reg_alpha=100, reg_lambda=100;, score=-163.076 total time=   2.6s
# [CV 5/5] END learning_rate=0.1, max_depth=5, min_child_weight=1, reg_alpha=100, reg_lambda=100;, score=-141.578 total time=   2.6s
# [CV 1/5] END learning_rate=0.1, max_depth=5, min_child_weight=5, reg_alpha=1, reg_lambda=1;, score=-122.245 total time=   2.6s
# [CV 2/5] END learning_rate=0.1, max_depth=5, min_child_weight=5, reg_alpha=1, reg_lambda=1;, score=-123.473 total time=   2.6s
# [CV 3/5] END learning_rate=0.1, max_depth=5, min_child_weight=5, reg_alpha=1, reg_lambda=1;, score=-127.465 total time=   2.6s
# [CV 4/5] END learning_rate=0.1, max_depth=5, min_child_weight=5, reg_alpha=1, reg_lambda=1;, score=-161.885 total time=   2.6s
# [CV 5/5] END learning_rate=0.1, max_depth=5, min_child_weight=5, reg_alpha=1, reg_lambda=1;, score=-139.964 total time=   2.6s
# [CV 1/5] END learning_rate=0.1, max_depth=5, min_child_weight=5, reg_alpha=1, reg_lambda=5;, score=-122.739 total time=   2.6s
# [CV 2/5] END learning_rate=0.1, max_depth=5, min_child_weight=5, reg_alpha=1, reg_lambda=5;, score=-123.808 total time=   2.6s
# [CV 3/5] END learning_rate=0.1, max_depth=5, min_child_weight=5, reg_alpha=1, reg_lambda=5;, score=-127.341 total time=   2.6s
# [CV 4/5] END learning_rate=0.1, max_depth=5, min_child_weight=5, reg_alpha=1, reg_lambda=5;, score=-162.767 total time=   2.6s
# [CV 5/5] END learning_rate=0.1, max_depth=5, min_child_weight=5, reg_alpha=1, reg_lambda=5;, score=-139.669 total time=   2.6s
# [CV 1/5] END learning_rate=0.1, max_depth=5, min_child_weight=5, reg_alpha=1, reg_lambda=100;, score=-123.325 total time=   2.6s
# [CV 2/5] END learning_rate=0.1, max_depth=5, min_child_weight=5, reg_alpha=1, reg_lambda=100;, score=-124.741 total time=   2.6s
# [CV 3/5] END learning_rate=0.1, max_depth=5, min_child_weight=5, reg_alpha=1, reg_lambda=100;, score=-128.329 total time=   2.6s
# [CV 4/5] END learning_rate=0.1, max_depth=5, min_child_weight=5, reg_alpha=1, reg_lambda=100;, score=-162.996 total time=   2.6s
# [CV 5/5] END learning_rate=0.1, max_depth=5, min_child_weight=5, reg_alpha=1, reg_lambda=100;, score=-141.369 total time=   2.5s
# [CV 1/5] END learning_rate=0.1, max_depth=5, min_child_weight=5, reg_alpha=5, reg_lambda=1;, score=-121.970 total time=   2.6s
# [CV 2/5] END learning_rate=0.1, max_depth=5, min_child_weight=5, reg_alpha=5, reg_lambda=1;, score=-123.445 total time=   2.6s
# [CV 3/5] END learning_rate=0.1, max_depth=5, min_child_weight=5, reg_alpha=5, reg_lambda=1;, score=-127.032 total time=   2.6s
# [CV 4/5] END learning_rate=0.1, max_depth=5, min_child_weight=5, reg_alpha=5, reg_lambda=1;, score=-161.807 total time=   2.6s
# [CV 5/5] END learning_rate=0.1, max_depth=5, min_child_weight=5, reg_alpha=5, reg_lambda=1;, score=-139.320 total time=   2.6s
# [CV 1/5] END learning_rate=0.1, max_depth=5, min_child_weight=5, reg_alpha=5, reg_lambda=5;, score=-122.379 total time=   2.6s
# [CV 2/5] END learning_rate=0.1, max_depth=5, min_child_weight=5, reg_alpha=5, reg_lambda=5;, score=-123.353 total time=   2.6s
# [CV 3/5] END learning_rate=0.1, max_depth=5, min_child_weight=5, reg_alpha=5, reg_lambda=5;, score=-127.732 total time=   2.6s
# [CV 4/5] END learning_rate=0.1, max_depth=5, min_child_weight=5, reg_alpha=5, reg_lambda=5;, score=-162.661 total time=   2.6s
# [CV 5/5] END learning_rate=0.1, max_depth=5, min_child_weight=5, reg_alpha=5, reg_lambda=5;, score=-140.256 total time=   2.6s
# [CV 1/5] END learning_rate=0.1, max_depth=5, min_child_weight=5, reg_alpha=5, reg_lambda=100;, score=-123.438 total time=   2.6s
# [CV 2/5] END learning_rate=0.1, max_depth=5, min_child_weight=5, reg_alpha=5, reg_lambda=100;, score=-124.553 total time=   2.6s
# [CV 3/5] END learning_rate=0.1, max_depth=5, min_child_weight=5, reg_alpha=5, reg_lambda=100;, score=-128.432 total time=   2.6s
# [CV 4/5] END learning_rate=0.1, max_depth=5, min_child_weight=5, reg_alpha=5, reg_lambda=100;, score=-163.419 total time=   2.6s
# [CV 5/5] END learning_rate=0.1, max_depth=5, min_child_weight=5, reg_alpha=5, reg_lambda=100;, score=-141.826 total time=   2.6s
# [CV 1/5] END learning_rate=0.1, max_depth=5, min_child_weight=5, reg_alpha=100, reg_lambda=1;, score=-122.776 total time=   2.6s
# [CV 2/5] END learning_rate=0.1, max_depth=5, min_child_weight=5, reg_alpha=100, reg_lambda=1;, score=-123.978 total time=   2.6s
# [CV 3/5] END learning_rate=0.1, max_depth=5, min_child_weight=5, reg_alpha=100, reg_lambda=1;, score=-127.742 total time=   2.6s
# [CV 4/5] END learning_rate=0.1, max_depth=5, min_child_weight=5, reg_alpha=100, reg_lambda=1;, score=-162.459 total time=   2.6s
# [CV 5/5] END learning_rate=0.1, max_depth=5, min_child_weight=5, reg_alpha=100, reg_lambda=1;, score=-140.513 total time=   2.6s
# [CV 1/5] END learning_rate=0.1, max_depth=5, min_child_weight=5, reg_alpha=100, reg_lambda=5;, score=-122.810 total time=   2.6s
# [CV 2/5] END learning_rate=0.1, max_depth=5, min_child_weight=5, reg_alpha=100, reg_lambda=5;, score=-123.241 total time=   2.6s
# [CV 3/5] END learning_rate=0.1, max_depth=5, min_child_weight=5, reg_alpha=100, reg_lambda=5;, score=-128.044 total time=   2.6s
# [CV 4/5] END learning_rate=0.1, max_depth=5, min_child_weight=5, reg_alpha=100, reg_lambda=5;, score=-162.469 total time=   2.6s
# [CV 5/5] END learning_rate=0.1, max_depth=5, min_child_weight=5, reg_alpha=100, reg_lambda=5;, score=-141.363 total time=   2.6s
# [CV 1/5] END learning_rate=0.1, max_depth=5, min_child_weight=5, reg_alpha=100, reg_lambda=100;, score=-123.051 total time=   2.6s
# [CV 2/5] END learning_rate=0.1, max_depth=5, min_child_weight=5, reg_alpha=100, reg_lambda=100;, score=-124.335 total time=   2.6s
# [CV 3/5] END learning_rate=0.1, max_depth=5, min_child_weight=5, reg_alpha=100, reg_lambda=100;, score=-128.780 total time=   2.6s
# [CV 4/5] END learning_rate=0.1, max_depth=5, min_child_weight=5, reg_alpha=100, reg_lambda=100;, score=-162.932 total time=   2.6s
# [CV 5/5] END learning_rate=0.1, max_depth=5, min_child_weight=5, reg_alpha=100, reg_lambda=100;, score=-141.980 total time=   2.6s
# [CV 1/5] END learning_rate=0.1, max_depth=5, min_child_weight=100, reg_alpha=1, reg_lambda=1;, score=-122.266 total time=   2.5s
# [CV 2/5] END learning_rate=0.1, max_depth=5, min_child_weight=100, reg_alpha=1, reg_lambda=1;, score=-123.748 total time=   2.6s
# [CV 3/5] END learning_rate=0.1, max_depth=5, min_child_weight=100, reg_alpha=1, reg_lambda=1;, score=-127.161 total time=   2.5s
# [CV 4/5] END learning_rate=0.1, max_depth=5, min_child_weight=100, reg_alpha=1, reg_lambda=1;, score=-162.540 total time=   2.6s
# [CV 5/5] END learning_rate=0.1, max_depth=5, min_child_weight=100, reg_alpha=1, reg_lambda=1;, score=-139.777 total time=   2.5s
# [CV 1/5] END learning_rate=0.1, max_depth=5, min_child_weight=100, reg_alpha=1, reg_lambda=5;, score=-122.222 total time=   2.6s
# [CV 2/5] END learning_rate=0.1, max_depth=5, min_child_weight=100, reg_alpha=1, reg_lambda=5;, score=-123.807 total time=   2.5s
# [CV 3/5] END learning_rate=0.1, max_depth=5, min_child_weight=100, reg_alpha=1, reg_lambda=5;, score=-127.348 total time=   2.6s
# [CV 4/5] END learning_rate=0.1, max_depth=5, min_child_weight=100, reg_alpha=1, reg_lambda=5;, score=-162.316 total time=   2.5s
# [CV 5/5] END learning_rate=0.1, max_depth=5, min_child_weight=100, reg_alpha=1, reg_lambda=5;, score=-139.952 total time=   2.6s
# [CV 1/5] END learning_rate=0.1, max_depth=5, min_child_weight=100, reg_alpha=1, reg_lambda=100;, score=-123.257 total time=   2.6s
# [CV 2/5] END learning_rate=0.1, max_depth=5, min_child_weight=100, reg_alpha=1, reg_lambda=100;, score=-123.841 total time=   2.6s
# [CV 3/5] END learning_rate=0.1, max_depth=5, min_child_weight=100, reg_alpha=1, reg_lambda=100;, score=-128.702 total time=   2.5s
# [CV 4/5] END learning_rate=0.1, max_depth=5, min_child_weight=100, reg_alpha=1, reg_lambda=100;, score=-163.010 total time=   2.5s
# [CV 5/5] END learning_rate=0.1, max_depth=5, min_child_weight=100, reg_alpha=1, reg_lambda=100;, score=-141.231 total time=   2.6s
# [CV 1/5] END learning_rate=0.1, max_depth=5, min_child_weight=100, reg_alpha=5, reg_lambda=1;, score=-122.731 total time=   2.6s
# [CV 2/5] END learning_rate=0.1, max_depth=5, min_child_weight=100, reg_alpha=5, reg_lambda=1;, score=-124.708 total time=   2.5s
# [CV 3/5] END learning_rate=0.1, max_depth=5, min_child_weight=100, reg_alpha=5, reg_lambda=1;, score=-127.341 total time=   2.5s
# [CV 4/5] END learning_rate=0.1, max_depth=5, min_child_weight=100, reg_alpha=5, reg_lambda=1;, score=-161.908 total time=   2.5s
# [CV 5/5] END learning_rate=0.1, max_depth=5, min_child_weight=100, reg_alpha=5, reg_lambda=1;, score=-139.535 total time=   2.6s
# [CV 1/5] END learning_rate=0.1, max_depth=5, min_child_weight=100, reg_alpha=5, reg_lambda=5;, score=-122.680 total time=   2.6s
# [CV 2/5] END learning_rate=0.1, max_depth=5, min_child_weight=100, reg_alpha=5, reg_lambda=5;, score=-124.095 total time=   2.5s
# [CV 3/5] END learning_rate=0.1, max_depth=5, min_child_weight=100, reg_alpha=5, reg_lambda=5;, score=-127.680 total time=   2.5s
# [CV 4/5] END learning_rate=0.1, max_depth=5, min_child_weight=100, reg_alpha=5, reg_lambda=5;, score=-161.794 total time=   2.5s
# [CV 5/5] END learning_rate=0.1, max_depth=5, min_child_weight=100, reg_alpha=5, reg_lambda=5;, score=-139.730 total time=   2.6s
# [CV 1/5] END learning_rate=0.1, max_depth=5, min_child_weight=100, reg_alpha=5, reg_lambda=100;, score=-123.594 total time=   2.5s
# [CV 2/5] END learning_rate=0.1, max_depth=5, min_child_weight=100, reg_alpha=5, reg_lambda=100;, score=-124.575 total time=   2.6s
# [CV 3/5] END learning_rate=0.1, max_depth=5, min_child_weight=100, reg_alpha=5, reg_lambda=100;, score=-128.673 total time=   2.5s
# [CV 4/5] END learning_rate=0.1, max_depth=5, min_child_weight=100, reg_alpha=5, reg_lambda=100;, score=-163.000 total time=   2.5s
# [CV 5/5] END learning_rate=0.1, max_depth=5, min_child_weight=100, reg_alpha=5, reg_lambda=100;, score=-140.855 total time=   2.6s
# [CV 1/5] END learning_rate=0.1, max_depth=5, min_child_weight=100, reg_alpha=100, reg_lambda=1;, score=-123.196 total time=   2.6s
# [CV 2/5] END learning_rate=0.1, max_depth=5, min_child_weight=100, reg_alpha=100, reg_lambda=1;, score=-123.669 total time=   2.6s
# [CV 3/5] END learning_rate=0.1, max_depth=5, min_child_weight=100, reg_alpha=100, reg_lambda=1;, score=-128.049 total time=   2.6s
# [CV 4/5] END learning_rate=0.1, max_depth=5, min_child_weight=100, reg_alpha=100, reg_lambda=1;, score=-161.958 total time=   2.6s
# [CV 5/5] END learning_rate=0.1, max_depth=5, min_child_weight=100, reg_alpha=100, reg_lambda=1;, score=-140.494 total time=   2.6s
# [CV 1/5] END learning_rate=0.1, max_depth=5, min_child_weight=100, reg_alpha=100, reg_lambda=5;, score=-122.980 total time=   2.6s
# [CV 2/5] END learning_rate=0.1, max_depth=5, min_child_weight=100, reg_alpha=100, reg_lambda=5;, score=-123.711 total time=   2.6s
# [CV 3/5] END learning_rate=0.1, max_depth=5, min_child_weight=100, reg_alpha=100, reg_lambda=5;, score=-127.920 total time=   2.6s
# [CV 4/5] END learning_rate=0.1, max_depth=5, min_child_weight=100, reg_alpha=100, reg_lambda=5;, score=-162.642 total time=   2.6s
# [CV 5/5] END learning_rate=0.1, max_depth=5, min_child_weight=100, reg_alpha=100, reg_lambda=5;, score=-140.545 total time=   2.6s
# [CV 1/5] END learning_rate=0.1, max_depth=5, min_child_weight=100, reg_alpha=100, reg_lambda=100;, score=-123.244 total time=   2.5s
# [CV 2/5] END learning_rate=0.1, max_depth=5, min_child_weight=100, reg_alpha=100, reg_lambda=100;, score=-124.192 total time=   2.6s
# [CV 3/5] END learning_rate=0.1, max_depth=5, min_child_weight=100, reg_alpha=100, reg_lambda=100;, score=-128.758 total time=   2.5s
# [CV 4/5] END learning_rate=0.1, max_depth=5, min_child_weight=100, reg_alpha=100, reg_lambda=100;, score=-162.866 total time=   2.6s
# [CV 5/5] END learning_rate=0.1, max_depth=5, min_child_weight=100, reg_alpha=100, reg_lambda=100;, score=-141.750 total time=   2.6s
# [CV 1/5] END learning_rate=0.1, max_depth=7, min_child_weight=1, reg_alpha=1, reg_lambda=1;, score=-119.614 total time=   4.4s
# [CV 2/5] END learning_rate=0.1, max_depth=7, min_child_weight=1, reg_alpha=1, reg_lambda=1;, score=-118.625 total time=   4.4s
# [CV 3/5] END learning_rate=0.1, max_depth=7, min_child_weight=1, reg_alpha=1, reg_lambda=1;, score=-124.522 total time=   4.3s
# [CV 4/5] END learning_rate=0.1, max_depth=7, min_child_weight=1, reg_alpha=1, reg_lambda=1;, score=-157.245 total time=   4.4s
# [CV 5/5] END learning_rate=0.1, max_depth=7, min_child_weight=1, reg_alpha=1, reg_lambda=1;, score=-134.997 total time=   4.4s
# [CV 1/5] END learning_rate=0.1, max_depth=7, min_child_weight=1, reg_alpha=1, reg_lambda=5;, score=-119.431 total time=   4.4s
# [CV 2/5] END learning_rate=0.1, max_depth=7, min_child_weight=1, reg_alpha=1, reg_lambda=5;, score=-118.123 total time=   4.3s
# [CV 3/5] END learning_rate=0.1, max_depth=7, min_child_weight=1, reg_alpha=1, reg_lambda=5;, score=-123.742 total time=   4.3s
# [CV 4/5] END learning_rate=0.1, max_depth=7, min_child_weight=1, reg_alpha=1, reg_lambda=5;, score=-157.531 total time=   4.3s
# [CV 5/5] END learning_rate=0.1, max_depth=7, min_child_weight=1, reg_alpha=1, reg_lambda=5;, score=-135.548 total time=   4.3s
# [CV 1/5] END learning_rate=0.1, max_depth=7, min_child_weight=1, reg_alpha=1, reg_lambda=100;, score=-118.973 total time=   4.4s
# [CV 2/5] END learning_rate=0.1, max_depth=7, min_child_weight=1, reg_alpha=1, reg_lambda=100;, score=-119.257 total time=   4.4s
# [CV 3/5] END learning_rate=0.1, max_depth=7, min_child_weight=1, reg_alpha=1, reg_lambda=100;, score=-123.582 total time=   4.3s
# [CV 4/5] END learning_rate=0.1, max_depth=7, min_child_weight=1, reg_alpha=1, reg_lambda=100;, score=-158.064 total time=   4.3s
# [CV 5/5] END learning_rate=0.1, max_depth=7, min_child_weight=1, reg_alpha=1, reg_lambda=100;, score=-137.123 total time=   4.3s
# [CV 1/5] END learning_rate=0.1, max_depth=7, min_child_weight=1, reg_alpha=5, reg_lambda=1;, score=-118.672 total time=   4.4s
# [CV 2/5] END learning_rate=0.1, max_depth=7, min_child_weight=1, reg_alpha=5, reg_lambda=1;, score=-118.778 total time=   4.4s
# [CV 3/5] END learning_rate=0.1, max_depth=7, min_child_weight=1, reg_alpha=5, reg_lambda=1;, score=-124.191 total time=   4.4s
# [CV 4/5] END learning_rate=0.1, max_depth=7, min_child_weight=1, reg_alpha=5, reg_lambda=1;, score=-157.570 total time=   4.4s
# [CV 5/5] END learning_rate=0.1, max_depth=7, min_child_weight=1, reg_alpha=5, reg_lambda=1;, score=-135.990 total time=   4.4s
# [CV 1/5] END learning_rate=0.1, max_depth=7, min_child_weight=1, reg_alpha=5, reg_lambda=5;, score=-118.461 total time=   4.4s
# [CV 2/5] END learning_rate=0.1, max_depth=7, min_child_weight=1, reg_alpha=5, reg_lambda=5;, score=-119.129 total time=   4.4s
# [CV 3/5] END learning_rate=0.1, max_depth=7, min_child_weight=1, reg_alpha=5, reg_lambda=5;, score=-123.365 total time=   4.4s
# [CV 4/5] END learning_rate=0.1, max_depth=7, min_child_weight=1, reg_alpha=5, reg_lambda=5;, score=-157.031 total time=   4.4s
# [CV 5/5] END learning_rate=0.1, max_depth=7, min_child_weight=1, reg_alpha=5, reg_lambda=5;, score=-135.297 total time=   4.4s
# [CV 1/5] END learning_rate=0.1, max_depth=7, min_child_weight=1, reg_alpha=5, reg_lambda=100;, score=-119.055 total time=   4.5s
# [CV 2/5] END learning_rate=0.1, max_depth=7, min_child_weight=1, reg_alpha=5, reg_lambda=100;, score=-118.569 total time=   4.5s
# [CV 3/5] END learning_rate=0.1, max_depth=7, min_child_weight=1, reg_alpha=5, reg_lambda=100;, score=-123.802 total time=   4.4s
# [CV 4/5] END learning_rate=0.1, max_depth=7, min_child_weight=1, reg_alpha=5, reg_lambda=100;, score=-158.391 total time=   4.4s
# [CV 5/5] END learning_rate=0.1, max_depth=7, min_child_weight=1, reg_alpha=5, reg_lambda=100;, score=-136.415 total time=   4.3s
# [CV 1/5] END learning_rate=0.1, max_depth=7, min_child_weight=1, reg_alpha=100, reg_lambda=1;, score=-118.877 total time=   4.5s
# [CV 2/5] END learning_rate=0.1, max_depth=7, min_child_weight=1, reg_alpha=100, reg_lambda=1;, score=-117.879 total time=   4.6s
# [CV 3/5] END learning_rate=0.1, max_depth=7, min_child_weight=1, reg_alpha=100, reg_lambda=1;, score=-123.633 total time=   4.5s
# [CV 4/5] END learning_rate=0.1, max_depth=7, min_child_weight=1, reg_alpha=100, reg_lambda=1;, score=-157.161 total time=   4.6s
# [CV 5/5] END learning_rate=0.1, max_depth=7, min_child_weight=1, reg_alpha=100, reg_lambda=1;, score=-135.688 total time=   4.5s
# [CV 1/5] END learning_rate=0.1, max_depth=7, min_child_weight=1, reg_alpha=100, reg_lambda=5;, score=-118.577 total time=   4.5s
# [CV 2/5] END learning_rate=0.1, max_depth=7, min_child_weight=1, reg_alpha=100, reg_lambda=5;, score=-117.909 total time=   4.6s
# [CV 3/5] END learning_rate=0.1, max_depth=7, min_child_weight=1, reg_alpha=100, reg_lambda=5;, score=-123.430 total time=   4.5s
# [CV 4/5] END learning_rate=0.1, max_depth=7, min_child_weight=1, reg_alpha=100, reg_lambda=5;, score=-157.502 total time=   4.6s
# [CV 5/5] END learning_rate=0.1, max_depth=7, min_child_weight=1, reg_alpha=100, reg_lambda=5;, score=-135.243 total time=   4.5s
# [CV 1/5] END learning_rate=0.1, max_depth=7, min_child_weight=1, reg_alpha=100, reg_lambda=100;, score=-119.574 total time=   4.6s
# [CV 2/5] END learning_rate=0.1, max_depth=7, min_child_weight=1, reg_alpha=100, reg_lambda=100;, score=-119.051 total time=   4.6s
# [CV 3/5] END learning_rate=0.1, max_depth=7, min_child_weight=1, reg_alpha=100, reg_lambda=100;, score=-124.665 total time=   4.5s
# [CV 4/5] END learning_rate=0.1, max_depth=7, min_child_weight=1, reg_alpha=100, reg_lambda=100;, score=-157.943 total time=   4.6s
# [CV 5/5] END learning_rate=0.1, max_depth=7, min_child_weight=1, reg_alpha=100, reg_lambda=100;, score=-137.109 total time=   4.6s
# [CV 1/5] END learning_rate=0.1, max_depth=7, min_child_weight=5, reg_alpha=1, reg_lambda=1;, score=-119.208 total time=   4.3s
# [CV 2/5] END learning_rate=0.1, max_depth=7, min_child_weight=5, reg_alpha=1, reg_lambda=1;, score=-118.103 total time=   4.3s
# [CV 3/5] END learning_rate=0.1, max_depth=7, min_child_weight=5, reg_alpha=1, reg_lambda=1;, score=-123.763 total time=   4.3s
# [CV 4/5] END learning_rate=0.1, max_depth=7, min_child_weight=5, reg_alpha=1, reg_lambda=1;, score=-157.580 total time=   4.3s
# [CV 5/5] END learning_rate=0.1, max_depth=7, min_child_weight=5, reg_alpha=1, reg_lambda=1;, score=-136.235 total time=   4.2s
# [CV 1/5] END learning_rate=0.1, max_depth=7, min_child_weight=5, reg_alpha=1, reg_lambda=5;, score=-119.124 total time=   4.3s
# [CV 2/5] END learning_rate=0.1, max_depth=7, min_child_weight=5, reg_alpha=1, reg_lambda=5;, score=-118.561 total time=   4.4s
# [CV 3/5] END learning_rate=0.1, max_depth=7, min_child_weight=5, reg_alpha=1, reg_lambda=5;, score=-123.700 total time=   4.3s
# [CV 4/5] END learning_rate=0.1, max_depth=7, min_child_weight=5, reg_alpha=1, reg_lambda=5;, score=-157.126 total time=   4.4s
# [CV 5/5] END learning_rate=0.1, max_depth=7, min_child_weight=5, reg_alpha=1, reg_lambda=5;, score=-135.269 total time=   4.4s
# [CV 1/5] END learning_rate=0.1, max_depth=7, min_child_weight=5, reg_alpha=1, reg_lambda=100;, score=-119.113 total time=   4.4s
# [CV 2/5] END learning_rate=0.1, max_depth=7, min_child_weight=5, reg_alpha=1, reg_lambda=100;, score=-118.484 total time=   4.3s
# [CV 3/5] END learning_rate=0.1, max_depth=7, min_child_weight=5, reg_alpha=1, reg_lambda=100;, score=-123.872 total time=   4.4s
# [CV 4/5] END learning_rate=0.1, max_depth=7, min_child_weight=5, reg_alpha=1, reg_lambda=100;, score=-158.071 total time=   4.3s
# [CV 5/5] END learning_rate=0.1, max_depth=7, min_child_weight=5, reg_alpha=1, reg_lambda=100;, score=-137.150 total time=   4.4s
# [CV 1/5] END learning_rate=0.1, max_depth=7, min_child_weight=5, reg_alpha=5, reg_lambda=1;, score=-119.249 total time=   4.4s
# [CV 2/5] END learning_rate=0.1, max_depth=7, min_child_weight=5, reg_alpha=5, reg_lambda=1;, score=-118.113 total time=   4.3s
# [CV 3/5] END learning_rate=0.1, max_depth=7, min_child_weight=5, reg_alpha=5, reg_lambda=1;, score=-124.031 total time=   4.3s
# [CV 4/5] END learning_rate=0.1, max_depth=7, min_child_weight=5, reg_alpha=5, reg_lambda=1;, score=-157.520 total time=   4.3s
# [CV 5/5] END learning_rate=0.1, max_depth=7, min_child_weight=5, reg_alpha=5, reg_lambda=1;, score=-134.565 total time=   4.3s
# [CV 1/5] END learning_rate=0.1, max_depth=7, min_child_weight=5, reg_alpha=5, reg_lambda=5;, score=-118.854 total time=   4.3s
# [CV 2/5] END learning_rate=0.1, max_depth=7, min_child_weight=5, reg_alpha=5, reg_lambda=5;, score=-118.233 total time=   4.4s
# [CV 3/5] END learning_rate=0.1, max_depth=7, min_child_weight=5, reg_alpha=5, reg_lambda=5;, score=-123.902 total time=   4.3s
# [CV 4/5] END learning_rate=0.1, max_depth=7, min_child_weight=5, reg_alpha=5, reg_lambda=5;, score=-158.101 total time=   4.4s
# [CV 5/5] END learning_rate=0.1, max_depth=7, min_child_weight=5, reg_alpha=5, reg_lambda=5;, score=-135.505 total time=   4.4s
# [CV 1/5] END learning_rate=0.1, max_depth=7, min_child_weight=5, reg_alpha=5, reg_lambda=100;, score=-119.016 total time=   4.4s
# [CV 2/5] END learning_rate=0.1, max_depth=7, min_child_weight=5, reg_alpha=5, reg_lambda=100;, score=-117.563 total time=   4.4s
# [CV 3/5] END learning_rate=0.1, max_depth=7, min_child_weight=5, reg_alpha=5, reg_lambda=100;, score=-124.093 total time=   4.4s
# [CV 4/5] END learning_rate=0.1, max_depth=7, min_child_weight=5, reg_alpha=5, reg_lambda=100;, score=-158.257 total time=   4.3s
# [CV 5/5] END learning_rate=0.1, max_depth=7, min_child_weight=5, reg_alpha=5, reg_lambda=100;, score=-136.524 total time=   4.4s
# [CV 1/5] END learning_rate=0.1, max_depth=7, min_child_weight=5, reg_alpha=100, reg_lambda=1;, score=-119.309 total time=   4.5s
# [CV 2/5] END learning_rate=0.1, max_depth=7, min_child_weight=5, reg_alpha=100, reg_lambda=1;, score=-118.018 total time=   4.6s
# [CV 3/5] END learning_rate=0.1, max_depth=7, min_child_weight=5, reg_alpha=100, reg_lambda=1;, score=-124.193 total time=   4.4s
# [CV 4/5] END learning_rate=0.1, max_depth=7, min_child_weight=5, reg_alpha=100, reg_lambda=1;, score=-156.432 total time=   4.5s
# [CV 5/5] END learning_rate=0.1, max_depth=7, min_child_weight=5, reg_alpha=100, reg_lambda=1;, score=-135.703 total time=   4.6s
# [CV 1/5] END learning_rate=0.1, max_depth=7, min_child_weight=5, reg_alpha=100, reg_lambda=5;, score=-118.832 total time=   4.5s
# [CV 2/5] END learning_rate=0.1, max_depth=7, min_child_weight=5, reg_alpha=100, reg_lambda=5;, score=-117.920 total time=   4.5s
# [CV 3/5] END learning_rate=0.1, max_depth=7, min_child_weight=5, reg_alpha=100, reg_lambda=5;, score=-123.599 total time=   4.5s
# [CV 4/5] END learning_rate=0.1, max_depth=7, min_child_weight=5, reg_alpha=100, reg_lambda=5;, score=-158.308 total time=   4.5s
# [CV 5/5] END learning_rate=0.1, max_depth=7, min_child_weight=5, reg_alpha=100, reg_lambda=5;, score=-135.465 total time=   4.5s
# [CV 1/5] END learning_rate=0.1, max_depth=7, min_child_weight=5, reg_alpha=100, reg_lambda=100;, score=-118.968 total time=   4.5s
# [CV 2/5] END learning_rate=0.1, max_depth=7, min_child_weight=5, reg_alpha=100, reg_lambda=100;, score=-118.611 total time=   4.5s
# [CV 3/5] END learning_rate=0.1, max_depth=7, min_child_weight=5, reg_alpha=100, reg_lambda=100;, score=-123.954 total time=   4.5s
# [CV 4/5] END learning_rate=0.1, max_depth=7, min_child_weight=5, reg_alpha=100, reg_lambda=100;, score=-157.897 total time=   4.5s
# [CV 5/5] END learning_rate=0.1, max_depth=7, min_child_weight=5, reg_alpha=100, reg_lambda=100;, score=-136.958 total time=   4.5s
# [CV 1/5] END learning_rate=0.1, max_depth=7, min_child_weight=100, reg_alpha=1, reg_lambda=1;, score=-119.076 total time=   3.9s
# [CV 2/5] END learning_rate=0.1, max_depth=7, min_child_weight=100, reg_alpha=1, reg_lambda=1;, score=-117.703 total time=   3.7s
# [CV 3/5] END learning_rate=0.1, max_depth=7, min_child_weight=100, reg_alpha=1, reg_lambda=1;, score=-123.171 total time=   3.8s
# [CV 4/5] END learning_rate=0.1, max_depth=7, min_child_weight=100, reg_alpha=1, reg_lambda=1;, score=-157.777 total time=   3.8s
# [CV 5/5] END learning_rate=0.1, max_depth=7, min_child_weight=100, reg_alpha=1, reg_lambda=1;, score=-134.749 total time=   3.8s
# [CV 1/5] END learning_rate=0.1, max_depth=7, min_child_weight=100, reg_alpha=1, reg_lambda=5;, score=-119.177 total time=   3.9s
# [CV 2/5] END learning_rate=0.1, max_depth=7, min_child_weight=100, reg_alpha=1, reg_lambda=5;, score=-117.938 total time=   3.8s
# [CV 3/5] END learning_rate=0.1, max_depth=7, min_child_weight=100, reg_alpha=1, reg_lambda=5;, score=-123.532 total time=   3.8s
# [CV 4/5] END learning_rate=0.1, max_depth=7, min_child_weight=100, reg_alpha=1, reg_lambda=5;, score=-157.886 total time=   3.8s
# [CV 5/5] END learning_rate=0.1, max_depth=7, min_child_weight=100, reg_alpha=1, reg_lambda=5;, score=-134.847 total time=   3.8s
# [CV 1/5] END learning_rate=0.1, max_depth=7, min_child_weight=100, reg_alpha=1, reg_lambda=100;, score=-119.204 total time=   3.8s
# [CV 2/5] END learning_rate=0.1, max_depth=7, min_child_weight=100, reg_alpha=1, reg_lambda=100;, score=-117.982 total time=   3.8s
# ...
# [CV 3/5] END learning_rate=10, max_depth=9, min_child_weight=100, reg_alpha=5, reg_lambda=1;, score=-inf total time=   3.0s
# /home/skovtun/.local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:478: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# [CV 4/5] END learning_rate=10, max_depth=9, min_child_weight=100, reg_alpha=5, reg_lambda=1;, score=-inf total time=   3.1s
# /home/skovtun/.local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:478: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# [CV 5/5] END learning_rate=10, max_depth=9, min_child_weight=100, reg_alpha=5, reg_lambda=1;, score=-inf total time=   3.0s
# /home/skovtun/.local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:478: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# [CV 1/5] END learning_rate=10, max_depth=9, min_child_weight=100, reg_alpha=5, reg_lambda=5;, score=-inf total time=   3.0s
# /home/skovtun/.local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:478: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# [CV 2/5] END learning_rate=10, max_depth=9, min_child_weight=100, reg_alpha=5, reg_lambda=5;, score=-inf total time=   3.0s
# /home/skovtun/.local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:478: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# [CV 3/5] END learning_rate=10, max_depth=9, min_child_weight=100, reg_alpha=5, reg_lambda=5;, score=-inf total time=   3.0s
# /home/skovtun/.local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:478: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# [CV 4/5] END learning_rate=10, max_depth=9, min_child_weight=100, reg_alpha=5, reg_lambda=5;, score=-inf total time=   3.0s
# /home/skovtun/.local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:478: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# [CV 5/5] END learning_rate=10, max_depth=9, min_child_weight=100, reg_alpha=5, reg_lambda=5;, score=-inf total time=   2.9s
# /home/skovtun/.local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:478: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# [CV 1/5] END learning_rate=10, max_depth=9, min_child_weight=100, reg_alpha=5, reg_lambda=100;, score=-inf total time=   2.7s
# /home/skovtun/.local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:478: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# [CV 2/5] END learning_rate=10, max_depth=9, min_child_weight=100, reg_alpha=5, reg_lambda=100;, score=-inf total time=   2.5s
# /home/skovtun/.local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:478: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# [CV 3/5] END learning_rate=10, max_depth=9, min_child_weight=100, reg_alpha=5, reg_lambda=100;, score=-inf total time=   2.6s
# /home/skovtun/.local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:478: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# [CV 4/5] END learning_rate=10, max_depth=9, min_child_weight=100, reg_alpha=5, reg_lambda=100;, score=-inf total time=   2.6s
# /home/skovtun/.local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:478: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# [CV 5/5] END learning_rate=10, max_depth=9, min_child_weight=100, reg_alpha=5, reg_lambda=100;, score=-inf total time=   2.5s
# /home/skovtun/.local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:478: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# [CV 1/5] END learning_rate=10, max_depth=9, min_child_weight=100, reg_alpha=100, reg_lambda=1;, score=-inf total time=   3.0s
# /home/skovtun/.local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:478: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# [CV 2/5] END learning_rate=10, max_depth=9, min_child_weight=100, reg_alpha=100, reg_lambda=1;, score=-inf total time=   3.0s
# /home/skovtun/.local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:478: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# [CV 3/5] END learning_rate=10, max_depth=9, min_child_weight=100, reg_alpha=100, reg_lambda=1;, score=-inf total time=   3.0s
# /home/skovtun/.local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:478: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# [CV 4/5] END learning_rate=10, max_depth=9, min_child_weight=100, reg_alpha=100, reg_lambda=1;, score=-inf total time=   3.0s
# /home/skovtun/.local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:478: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# [CV 5/5] END learning_rate=10, max_depth=9, min_child_weight=100, reg_alpha=100, reg_lambda=1;, score=-inf total time=   2.9s
# /home/skovtun/.local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:478: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# [CV 1/5] END learning_rate=10, max_depth=9, min_child_weight=100, reg_alpha=100, reg_lambda=5;, score=-inf total time=   3.0s
# /home/skovtun/.local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:478: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# [CV 2/5] END learning_rate=10, max_depth=9, min_child_weight=100, reg_alpha=100, reg_lambda=5;, score=-inf total time=   3.0s
# /home/skovtun/.local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:478: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# [CV 3/5] END learning_rate=10, max_depth=9, min_child_weight=100, reg_alpha=100, reg_lambda=5;, score=-inf total time=   3.0s
# /home/skovtun/.local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:478: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# [CV 4/5] END learning_rate=10, max_depth=9, min_child_weight=100, reg_alpha=100, reg_lambda=5;, score=-inf total time=   3.0s
# /home/skovtun/.local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:478: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# [CV 5/5] END learning_rate=10, max_depth=9, min_child_weight=100, reg_alpha=100, reg_lambda=5;, score=-inf total time=   2.9s
# /home/skovtun/.local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:478: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# [CV 1/5] END learning_rate=10, max_depth=9, min_child_weight=100, reg_alpha=100, reg_lambda=100;, score=-inf total time=   2.7s
# /home/skovtun/.local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:478: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# [CV 2/5] END learning_rate=10, max_depth=9, min_child_weight=100, reg_alpha=100, reg_lambda=100;, score=-inf total time=   2.6s
# /home/skovtun/.local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:478: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# [CV 3/5] END learning_rate=10, max_depth=9, min_child_weight=100, reg_alpha=100, reg_lambda=100;, score=-inf total time=   2.8s
# /home/skovtun/.local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:478: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# [CV 4/5] END learning_rate=10, max_depth=9, min_child_weight=100, reg_alpha=100, reg_lambda=100;, score=-inf total time=   2.6s
# /home/skovtun/.local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:478: RuntimeWarning: overflow encountered in square
#   output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# /home/skovtun/.local/lib/python3.10/site-packages/sklearn/model_selection/_search.py:976: UserWarning: One or more of the test scores are non-finite: [-148.24100342 -149.29172363 -149.46287231 -148.83173523 -149.3417511
#  -149.45248413 -149.10612488 -149.37667542 -149.93776245 -148.23863525
#  -149.29287415 -149.4627594  -148.70904846 -149.3416687  -149.45248413
#  -149.10612488 -149.37619324 -149.93775024 -148.85957336 -148.95548401
#  -149.5357605  -148.89323425 -148.95905457 -149.31433411 -148.91678162
#  -149.30764771 -149.64533997 -135.21628265 -135.09506073 -136.34128113
#  -134.75638123 -135.30539703 -136.20346222 -135.61239166 -135.64543915
#  -136.2148056  -135.00627594 -135.26484375 -136.15184784 -134.71492462
#  -135.27619171 -136.3336319  -135.49360046 -135.58504028 -136.2155014
#  -135.09840851 -135.12909393 -136.00820312 -135.24450378 -135.1959549
#  -136.13953094 -135.47313843 -135.55948792 -136.16191101 -131.00052338
#  -130.87492065 -131.39978638 -131.03998566 -130.65657959 -131.24634399
#  -130.64760895 -130.53228912 -131.66840973 -130.97785034 -130.75598145
#  -131.33816833 -130.69540405 -130.91912537 -131.09052734 -130.73101349
#  -130.82483826 -131.27776642 -130.49540253 -130.67588654 -131.38319397
#  -130.48214111 -130.32112427 -131.65382385 -130.55093842 -130.87993927
#  -131.4385849  -131.17483673 -130.67319031 -129.29834442 -131.00753632
#  -130.48455811 -129.36075439 -129.9667984  -129.96654968 -129.5473175
#  -130.90901489 -130.64526215 -129.30944824 -130.84401703 -130.26020813
#  -129.55569763 -129.70315399 -129.89947205 -129.52721863 -129.41742401
#  -128.95158386 -129.60603333 -128.9981781  -128.85606689 -129.25729675
#  -129.02964478 -129.08567352 -129.77720642 -142.58115234 -143.50431824
#  -142.1994751  -143.97543335 -143.20447693 -142.57484131 -142.835495
#  -143.7339386  -143.2009552  -142.89384766 -143.51719666 -142.1993988
#  -143.829422   -143.11897278 -142.57397766 -142.835495   -143.75572815
#  -143.20097961 -143.03605347 -143.11636047 -143.66001587 -142.97076416
#  -142.93494568 -143.44569702 -142.70239258 -143.07857056 -143.12032166
#  -150.68695984 -149.94307556 -145.83237915 -150.29446411 -149.76185608
#  -145.39659119 -147.71306763 -147.85540771 -144.35623169 -150.77878723
#  -149.43592834 -145.61671448 -150.42714844 -150.31854858 -145.84786072
#  -147.88563538 -147.24537354 -144.76720276 -148.9723114  -148.5558075
#  -145.10682678 -149.05969238 -148.5986969  -145.41768188 -147.63406982
#  -146.08685608 -145.00097656 -167.43904114 -163.72757263 -152.98094788
#  -166.27568054 -164.94746094 -153.43678589 -158.79067993 -159.83616943
#  -153.17449646 -167.78179016 -164.65584717 -152.50608826 -166.15934753
#  -164.79990845 -153.16053467 -160.14831543 -158.84489136 -153.16839294
#  -160.89823303 -159.24140625 -152.61915283 -160.8545166  -159.58560181
#  -151.45999146 -157.18074036 -156.86703491 -152.51790466 -175.63683472
#  -171.40755615 -158.03599243 -175.81070557 -170.20113831 -157.82832031
#  -163.87748413 -164.55605164 -156.84881897 -175.09614258 -170.56784973
#  -158.59085388 -175.10382385 -171.4085144  -158.21652527 -163.82113647
#  -163.50404053 -156.77224121 -170.36641846 -169.66748962 -158.29353333
#  -170.32837524 -168.48390503 -158.0777832  -163.94694824 -162.42979736
#  -155.89141235 -158.55135193 -155.97662048 -152.74719238 -157.31590881
#  -156.57987671 -151.79486084 -152.72904053 -154.39576111 -154.95317383
#  -157.96503906 -155.89513245 -152.8480957  -158.14020386 -156.57905884
#  -151.26338196 -152.6499176  -154.32935486 -154.9609314  -157.05398865
#  -156.69595947 -151.97872009 -154.18128052 -155.36305847 -152.89671021
#  -152.75134888 -156.04079285 -152.92944641 -208.30250854 -205.14926147
#  -187.13163452 -206.09697571 -200.70028687 -185.14302063 -195.564328
#  -196.54295654 -183.01140747 -208.04613953 -203.98921204 -185.07434387
#  -205.43474731 -202.64736938 -186.63487244 -194.5065979  -194.66038818
#  -180.99686279 -201.35166931 -199.55682373 -185.72194214 -200.20647888
#  -197.17715149 -185.74238281 -193.61783752 -193.16430969 -182.17156982
#  -274.91621704 -265.1047821  -223.63785095 -271.77365417 -261.60354309
#  -222.75652771 -243.00335388 -240.77216492 -216.24906311 -274.07847595
#  -265.16888733 -222.52170715 -270.91342468 -266.14219666 -222.27169189
#  -243.55105896 -239.52350464 -216.4755188  -256.54382019 -255.92387695
#  -222.99823303 -258.89360962 -251.06031494 -220.85975952 -239.46338196
#  -239.18581543 -216.58848267 -291.48237915 -278.24147949 -224.026651
#  -287.78873291 -270.80855713 -223.64513245 -248.0353241  -243.44725952
#  -216.7510376  -289.54373169 -274.04385986 -225.31204834 -286.80704346
#  -270.07065735 -225.69676208 -247.00091858 -246.51112671 -217.32195435
#  -288.14630127 -282.60360107 -232.91933289 -288.57106934 -277.49992065
#  -233.11660767 -253.17998657 -249.0340271  -221.36576233          -inf
#           -inf          -inf          -inf          -inf          -inf
#           -inf          -inf          -inf          -inf          -inf
#           -inf          -inf          -inf          -inf          -inf
#           -inf          -inf          -inf          -inf          -inf
#           -inf          -inf          -inf          -inf          -inf
#           -inf          -inf          -inf          -inf          -inf
#           -inf          -inf          -inf          -inf          -inf
#           -inf          -inf          -inf          -inf          -inf
#           -inf          -inf          -inf          -inf          -inf
#           -inf          -inf          -inf          -inf          -inf
#           -inf          -inf          -inf          -inf          -inf
#           -inf          -inf          -inf          -inf          -inf
#           -inf          -inf          -inf          -inf          -inf
#           -inf          -inf          -inf          -inf          -inf
#           -inf          -inf          -inf          -inf          -inf
#           -inf          -inf          -inf          -inf          -inf
#           -inf          -inf          -inf          -inf          -inf
#           -inf          -inf          -inf          -inf          -inf
#           -inf          -inf          -inf          -inf          -inf
#           -inf          -inf          -inf          -inf          -inf
#           -inf          -inf          -inf          -inf          -inf
#           -inf          -inf]
#   warnings.warn(
# /home/skovtun/.local/lib/python3.10/site-packages/sklearn/model_selection/_search.py:987: RuntimeWarning: invalid value encountered in subtract
#   (array - array_means[:, np.newaxis]) ** 2, axis=1, weights=weights
# [CV 5/5] END learning_rate=10, max_depth=9, min_child_weight=100, reg_alpha=100, reg_lambda=100;, score=-inf total time=   2.6s
# Best parameters: {'learning_rate': 0.1, 'max_depth': 9, 'min_child_weight': 100, 'reg_alpha': 5, 'reg_lambda': 5}

# %%
print(len(y_pred_test),len(target_multi_test_200[:,0]))
# Out:
# 10983 21394

# %%
#Best parameters: {'learning_rate': 0.1, 'max_depth': 9, 'min_child_weight': 100, 'reg_alpha': 5, 'reg_lambda': 5}
# Get the best model from the grid search
best_model = XGBRegressor(n_jobs=-1,tree_method="gpu_hist", sampling_method='gradient_based',
                         learning_rate = 0.1, max_depth = 9, min_child_weight = 100, reg_alpha = 5,
                          reg_lambda = 5)

# Use the best model to make predictions on the train set
best_model.fit(multi_train_500,target_multi_train_200[:,0] ) 
y_pred = best_model.predict(multi_train_500) 
# Calculate the mean squared error on the train set
pe = scipy.stats.pearsonr(target_multi_train_200[:,0], y_pred)
print("Pearson Error on train set:", pe)
# Use the best model to make predictions on the test set
y_pred_test = best_model.predict(multi_test_500) 
# Calculate the mean squared error on the train set
pe_test = scipy.stats.pearsonr(target_multi_test_200[:,0], y_pred_test)
print("Pearson Error on test set:", pe_test)
# Out:
# Pearson Error on train set: PearsonRResult(statistic=0.8959998662929849, pvalue=0.0)
# Pearson Error on test set: PearsonRResult(statistic=0.7805675900860645, pvalue=0.0)

# %%
# Repeat for all other 199 targets.
